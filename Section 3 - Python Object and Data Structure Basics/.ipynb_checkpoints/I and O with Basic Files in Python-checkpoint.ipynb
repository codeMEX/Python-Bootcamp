# %%
# %%writefile myfile.txt
# Hello this is a text file
# this is the second line
# this is the third line
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')

# %%
# mytile = open('whoops_wront.txt') # this is the wrong file name which will result in an error

# %%
pwd
# Out:
# 'C:\\Users\\Ren\\Documents\\Python Bootcamp\\Section 3 - Python Object and Data Structure Basics'

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is a text file \nthis is the second line\nthis is the third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file \nthis is the second line\nthis is the third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file \nthis is the second line\nthis is the third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file \n',
#  'this is the second line\n',
#  'this is the third line\n']

# %% [markdown]
# # **File Locations**
#
# If want to open files at another location on your computer, simply pass in the entire file path.
#
# For Windows you need to use double \ so python doesn't treat the second \ as an scape chareacter, a file path is in form:
#
#     myfile = open("C:\\Users\\UserName\\folder\\test.txt")
#
# For MacOS and Linux you use slashes in the oppocite direction:
#
#     myfile = opne("/Users/YourUserName/Folder/myfile.txt")

# %%
pwd
# Out:
# 'C:\\Users\\Ren\\Documents\\Python Bootcamp\\Section 3 - Python Object and Data Structure Basics'

# %%
myfile.close()

# %%
with open ('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello this is a text file \nthis is the second line\nthis is the third line\n'

# %%
with open('myfile.txt',mode='r') as myfile:
    contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file \nthis is the second line\nthis is the third line\n'

# %%
#with open('myfile.txt',mode='w') as myfile:
#    contents = myfile.read()

# %% [markdown]
# # **Read, Write, Appending Modes**
#
# - **mode='r'** is read only
# - **mode='w'** is write only (will overwrite files or create new!)
# - **mode='a'** is append only (will add on to files)
# - **mode='r+'** is reading and writing
# - **mode='w+'** is writing and reading (Overwrites existing files or creates a new file!)

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# Out:
# Overwriting my_new_file.txt

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %%
with open('my_new_file.txt',mode='a') as f:
    f.write('\nFOUR ON FOURTH')

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
#
# FOUR ON FOURTH

# %%
with open('dhfjdkshfjdks.txt',mode='w') as f:
    f.write('I CREATED THIS FILE!')

# %%
with open('dhfjdkshfjdks.txt',mode='r') as f:
    print(f.read())
# Out:
# I CREATED THIS FILE!
